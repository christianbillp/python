# %% [markdown]
# # Fall 2010

# %% [markdown]
# #### QUESTION 1: Consider the data illustrated in the scatter plot in Figure 1. Each data object has two attributes, x and y. Which axes correspond to the two principal components?

# %% [markdown]
# TIP: Look for the line which best cuts the data-cloud on the long side. Think, "prepare a sandwich bread" before "cutting it in two for sharing".

# %% [markdown]
# #### QUESTION 2: Consider the data illustrated in the scatter plot in Figure 1. Which statement is correct? The attributes x and y
# TIP: The data cloud tilts down at the right side, indicating negative correlation.

# %% [markdown]
# #### QUESTION 3: Consider the data illustrated in the scatter plot in Figure 1. Which statement is correct?

# %% [markdown]
# #### QUESTION 4: In the agglomerative hierarchical clustering algorithm, which clusters are merged first?

# %% [markdown]
# #### QUESTION 5: Continuing question 4: At which distance is D and E merged (what is the value of d3 in the dendrogram in Figure 4)?

# %% [markdown]
# #### QUESTION 6: Continuing question 4–5: At which distance is C and {A,B} merged (what is the value of d2 in the dendrogram in Figure 4)?

# %% [markdown]
# #### QUESTION 7: How will F, G, and H in Figure 5 be classified using the classification tree in Figure 6?
# TIP: It's not obvious what the y-value for F is, look closely and count dots for accurate indication.

# %% [markdown]
# #### QUESTION 8: Using the cosine distances in Figure 7, how will F, G, and H be classified using the nearest neighbor classifier (1 nearest neighbor)?
# TIP: Look at the distance table, new data is the same as closest classified datapoint.
# TIP: Annotate the table with class labels over observations. (P)ositive and (N)egative.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### QUESTION 9: Using the cosine distances in Figure 7, how will F, G, and H be classified using the 3-nearest neighbors classifier?

# %% [markdown]
# #### QUESTION 10: Using the labelled data objects (A–E) in Figure 5, what is the leave-one-out estimate of the generalization error (classification error rate) for k = 1 nearest neighbor classifier based on cosine distances given in Figure 3?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TIP: Draw a ring (color corresponds to nearest observation class) around an observation and keep expanding. When an observation is hit, stop. If the class (color) of the nearest observation matches, move on to the next observation. If there is a mismatch count an error. 3 circles have different colors than their observation out of 5.

# %% [markdown]
# #### QUESTION 11: Using the labelled data objects (A–E) in Figure 5, what is the leave-one-out estimate of the generalization error (classification error rate) for k = 3 nearest neighbor classifier based on cosine distances given in Figure 3?

# %% [markdown]
# #### QUESTION 12: Using the logistic regression classifier described above, how will F, G, and H in Figure 5 be classified?

# %% [markdown]
# TIP: Create function from weights and intercept.
# $$w_0 + w_xx + w_yy$$
# $$0=0 + 2x + 3y$$
# $$3y = -2x$$
# $$y = - (2/3)x$$

# %%
def is_positive(x, y):
    if y > -2/3*x:
        return True
    else:
        return False

# %%
is_positive(x=1.9, y=0.2)
# Out:
# True

# %%
is_positive(x=0.5, y=-1)
# Out:
# False

# %%
is_positive(x=1.5, y=0.5)
# Out:
# True

# %% [markdown]
# #### QUESTION 13: In the logistic regression classifier described above, what is the shape of the decision boundary?

# %% [markdown]
# #### QUESTION 14: In the Na¨ıve Bayes classifier described above, what is the posterior probability that data object F in Figure 8 is Positive?

# %% [markdown]
# #### QUESTION 15: Using the Na¨ıve Bayes classifier described above, how will F, G, and H in Figure 8 be classified?

# %% [markdown]
# #### QUESTION 16: In a store five consumers denoted C1–C5 have purchased the items given in Figure 9, where 1 indicate that a given consumer purchased the item and 0 that the consumer did not purchase the item.

# %% [markdown]
# #### QUESTION 17: We note that association rules can be written interchangeably as {A,B}! {C} or {C} {A,B}. What is the confidence of the rule {Diaper} {Bread,Milk} and {Beer} {Jam}?

# %% [markdown]
# #### QUESTION 18: Consider a dataset where we have four different features: A, B, C and D that are used in a linear regression problem. Figure 10 shows the sum of square residual error, i.e.,  SSE = Pi(ytrue i −yest i )2 on the test sets averaged across 10 cross-validation folds when using different combinations of the features. We will apply a backward feature selection algorithm. Which feature set will the selection algorithm choose?

# %% [markdown]
# TIP: Remember that after removing a feature, you cannot use it again. When selecting A, B, D no two-feature options with C are available.

# %% [markdown]
# #### QUESTION 19: Which statement about the kmeans algorithm and the Gaussian Mixture Model (GMM) is wrong?

# %% [markdown]
# #### QUESTION 20: In a study of prostate cancer, a classification model was created with the confusion matrix illustrated in Figure 11. True indicates that the tumor is malignant and false that it is benign. Which statement is correct?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### QUESTION 21: Three different classification approaches have been used on a dataset. The training data as well as the decision boundaries obtained for each approach is given in figure 12A–12C. Which classification methods have been used to generate each of the decision boundaries A, B and C?

# %% [markdown]
# TIP: Decision trees have 90 degree turns on their decision boundries. Logistic regression has a linear decision boundry.

# %% [markdown]
# #### QUESTION 22: Which statement about crossvalidation is correct?

# %% [markdown]
# #### QUESTION 23: When training a decision tree we will use the classification error as impurity measure I(t) given by I(t) = 1 − maxi[p(i|t)] where p(i|t) denotes the fraction of data objects belonging to class i at a given node t. We will use Hunt’s algorithm to grow the tree and recall that the purity gain is given by  = I(Parent) −Pk j=1 N(vj ) N I(vj) where N is the total number of data objects at the parent node, k is the number of child nodes and N(vj) is the number of data objects associated with the child node, vj . We will consider classification of wine into Red and White wine. At a potential split we have

# %% [markdown]
# Challenge: Naive Bayes, GMM, purity gain.

# %% [markdown]
# #### QUESTION 24: In the analysis of car prices the following attributes were collected for each car: The number of kilometers the car had driven (denoted mileage), the make (brand) of the car (denoted make) and the year the car was produced (denoted year). Which statement about the three attributes is correct?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### QUESTION 25: We consider a data set with 10 data objects denoted A–J, that theoretically should lie in one cluster; however, we suspect there might be one or more outliers in the data set. To examine this, we plot the distance to the k’th nearest neighbor for k 2 {1, 2, 3, 4} (see Figure 13). Based on the plot, which statement is false?

# %% [markdown]
# # Fall 2011

# %% [markdown]
# Question 1. Consider the data set described in Table 1. Which statement about the attributes in the data set is correct?

# %% [markdown]
# Question 2. Consider the data set described in Table 1. Each attribute in the data set is standardized, and we carry out a principal component analysis (PCA) on the standardized input data, x1{x6. The singular values obtained are: 1 = 17:0, 2 = 15:2, 3 = 13:1, 4 = 13:0, 5 = 11:8, 6 = 11:3. The rst and second principal component directions are: Which one of the following statements is incorrect?

# %%
data = [17.0, 15.2, 13.1, 13.0, 11.8, 11.3]
var_exp = [float(n)/sum(data) for n in data]
var_exp
# Out:
# [0.20884520884520882,
#  0.18673218673218672,
#  0.1609336609336609,
#  0.1597051597051597,
#  0.14496314496314497,
#  0.13882063882063883]

# %% [markdown]
# Question 3. Consider the data set in Table 1. We would like to predict the birth weight y based on the six attributes x1{x6. In order to do so we t a linear regression model with Forward selection as well as a linear regression with Backward selection using ve-fold cross-validation. Which of the following statements is correct?

# %% [markdown]
# Question 4. A linear regression model has been tted to the data in Table 1 using ve-fold crossvalidated Forward and Backward selection. Figure 1 shows the results in terms of which attributes were selected in each cross-validation fold. Which of the following statements is correct?

# %% [markdown]
# Question 5. A linear regression model has been tted to the data set in Table 1 where the attributes Age and PV have been removed since they were neither selected by Forward nor Backward selection. Furthermore, they are correlated with the remaining attributes. The tted model, f(x), is given by

# %% [markdown]
# Question 6. Ten mothers, denoted m1;m2; : : : ;m10, have been randomly selected from the data set described in Table 1. We here consider only the attributes MW, HT, UI, BW, and the continuous attribute MW has been binarized in terms of the attribute's values being above or below the median value of all the 189 observations. BWL and BWH denotes a low birth weight baby and a high birth weight baby respectively. The binarized data is given in Table 2. What are all the frequent itemsets with support greater than 45%?

# %% [markdown]
# Question 7. Consider the data in Table 2. What is the condence of the association rule fBWLg   fMWL, HTNg?

# %% [markdown]
# Question 8. Consider the data set in Table 2. A mother who has a low weight, does not have a history of hypertension nor uterine irritability is just about to give birth to a baby. We would like to predict if the baby will have a low birth weight. For the mother we have MWL = 1, HTN = 1, UIN = 1. We will classify the mother considering only the attributes MWL; HTN; and UIN; based on the data in Table 2 only. We will use a Nave Bayes classier that assumes independence between these attributes. What is the probability that the weight of the baby will be low, i.e., BWL = 1?

# %% [markdown]
# Question 9. Table 3 shows the Euclidean distance between the ten selected mothers based on all the 6 attributes x1{x6 in Table 1. We recall that the KNN density and average relative density for the observation x is given by density(x;K) =  1 K X y2N(x;K) distance(x; y) 􀀀1 a.r.d.(x;K) = density(x;K) 1 K X y2N(x;K) density(y;K) ; where N(x;K) is the set of K nearest neighbors of observation x and a.r.d(x;K) is the average relative density of x using K nearest neighbors. Based on the the data in Table 3, what is the average relative density for observation m2 for K = 2 nearest neighbors?

# %% [markdown]
# Question 10. Out of the ten mothers in the data in Table 2, m3, m4, m6, m7, m8, and m9 gave birth to a baby with low birth weight, i.e., BWL = 1. Based on the distances in Table 3, we will use K-nearest neighbor classication with K = 1 to classify each observation. The performance of the classier is estimated using leave-one-out cross-validation. Which of the following statements about the leaveone- out crossvalidation error is incorrect?

# %% [markdown]
# Question 11. In a very large unpublished study the following ndings were made: • 60% of mothers that have a history of hypertension give birth to a baby with low birth weight. • 8% of mothers that do not have a history of hypertension give birth to a baby with low birth weight. • 10% of all mothers have a history of hypertension. A mother gives birth to a baby with low birth weight. What is the probability the mother has a history of hypertension according to the unpublished study?

# %% [markdown]
# Question 12. We will consider a two-class classication problem. A classier has been trained that gives a score t to each observation. Figure 2 shows the value of the score for each observation, as well as the density of the two classes as a function of the score t estimated using a kernel density estimator. Figure 3 shows the ROC curves for three dierent classiers. Which of the three ROC curves corresponds to the classier that scores the observations according to Figure 2?

# %% [markdown]
# Question 13. A dataset with two attributes x1 and x2 contains the four classes illustrated in Figure 4. Which of the following statements is correct?

# %% [markdown]
# Question 14. Three dierent classiers are trained on all the available data in Figure 4 using only x1 and x2 as attributes. The data as well as the decision boundaries of each of the three classiers are given in Figure 5. Which of the following statements is correct?

# %% [markdown]
# Question 15. We would like to combine classiers in order to improve the classication performance. Which one of the following statements is correct?

# %% [markdown]
# Question 16. Out of the three classiers in Figure 5, it turns out that classier B is the worst performing classier. In Figure 6 we inspect the confusion matrix of this classier. Which of the following statements is incorrect?

# %% [markdown]
# Question 17. Which of the following statements about decision trees is incorrect?

# %% [markdown]
# Question 18. The data in Table 4 shows whether or not eight keywords occur in ve news articles (i.e., the data has eight attributes and ve observations). Which statement about the data is incorrect?

# %% [markdown]
# Question 19. What is the empirical covariance between the two attributes \Opera" and \Orchestra" in the data in Table 4?

# %% [markdown]
# Question 20. The following proposed clustering procedure (step 1 to 3 below) for the ve articles in Table 4 contains an error: 1) The articles are clustered using k-means with k = 2. 2) The simple matching coecient (SMC) is used as similarity measure. 3) The centroids are computed as the component-wise mean. Which statement about the erroneous clustering procedure is correct?

# %% [markdown]
# Question 21. Use agglomerative hierarchical clustering with complete linkage to cluster the ve articles in Table 4. As a distance measure use d(x; y) = 1􀀀J(x; y) where J is the Jaccard coecient. Which of the four clusterings in Figure 7 is the resulting hierarchical clustering?

# %% [markdown]
# Question 22. You are told that the news articles in Table 4 belong to two groups (indicated in red and black respectively in the table):

# %% [markdown]
# Question 23. Consider a decision tree optimized to classify the news articles in Table 4 into the two groups described in Question 22. The decision tree is optimized with Hunt's algorithm using the Gini index as impurity measure, and no pruning is performed. Which of the following statements is correct?

# %% [markdown]
# Question 24. Which statement about linear regression is incorrect?

# %% [markdown]
# Question 25. Consider the following data x -1 0 1 2 y 2 2 4 8 A linear regression model, f(x) = w0 + w1x; is t to the data using the least square method. What are the optimal parameters?

# %% [markdown]
# Question 26. Consider the data in Table 5 illustrated by the boxplot in Figure 8. Which statement is incorrect?
