# %% [markdown]
# # Fall 2010

# %% [markdown]
# #### QUESTION 1: Consider the data illustrated in the scatter plot in Figure 1. Each data object has two attributes, x and y. Which axes correspond to the two principal components?

# %% [markdown]
# TIP: Look for the line which best cuts the data-cloud on the long side. Think, "prepare a sandwich bread" before "cutting it in two for sharing".

# %% [markdown]
# #### QUESTION 2: Consider the data illustrated in the scatter plot in Figure 1. Which statement is correct? The attributes x and y
# TIP: The data cloud tilts down at the right side, indicating negative correlation.

# %% [markdown]
# #### QUESTION 3: Consider the data illustrated in the scatter plot in Figure 1. Which statement is correct?

# %% [markdown]
# #### QUESTION 4: In the agglomerative hierarchical clustering algorithm, which clusters are merged first?

# %% [markdown]
# #### QUESTION 5: Continuing question 4: At which distance is D and E merged (what is the value of d3 in the dendrogram in Figure 4)?

# %% [markdown]
# #### QUESTION 6: Continuing question 4–5: At which distance is C and {A,B} merged (what is the value of d2 in the dendrogram in Figure 4)?

# %% [markdown]
# #### QUESTION 7: How will F, G, and H in Figure 5 be classified using the classification tree in Figure 6?
# TIP: It's not obvious what the y-value for F is, look closely and count dots for accurate indication.

# %% [markdown]
# #### QUESTION 8: Using the cosine distances in Figure 7, how will F, G, and H be classified using the nearest neighbor classifier (1 nearest neighbor)?
# TIP: Look at the distance table, new data is the same as closest classified datapoint.
# TIP: Annotate the table with class labels over observations. (P)ositive and (N)egative.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### QUESTION 9: Using the cosine distances in Figure 7, how will F, G, and H be classified using the 3-nearest neighbors classifier?

# %% [markdown]
# #### QUESTION 10: Using the labelled data objects (A–E) in Figure 5, what is the leave-one-out estimate of the generalization error (classification error rate) for k = 1 nearest neighbor classifier based on cosine distances given in Figure 3?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TIP: Draw a ring (color corresponds to nearest observation class) around an observation and keep expanding. When an observation is hit, stop. If the class (color) of the nearest observation matches, move on to the next observation. If there is a mismatch count an error. 3 circles have different colors than their observation out of 5.

# %% [markdown]
# #### QUESTION 11: Using the labelled data objects (A–E) in Figure 5, what is the leave-one-out estimate of the generalization error (classification error rate) for k = 3 nearest neighbor classifier based on cosine distances given in Figure 3?

# %% [markdown]
# #### QUESTION 12: Using the logistic regression classifier described above, how will F, G, and H in Figure 5 be classified?

# %% [markdown]
# TIP: Create function from weights and intercept.
# $$w_0 + w_xx + w_yy$$
# $$0=0 + 2x + 3y$$
# $$3y = -2x$$
# $$y = - (2/3)x$$

# %%
def is_positive(x, y):
    if y > -2/3*x:
        return True
    else:
        return False

# %%
is_positive(x=1.9, y=0.2)
# Out:
# True

# %%
is_positive(x=0.5, y=-1)
# Out:
# False

# %%
is_positive(x=1.5, y=0.5)
# Out:
# True

# %% [markdown]
# #### QUESTION 13: In the logistic regression classifier described above, what is the shape of the decision boundary?

# %% [markdown]
# #### QUESTION 14: In the Na¨ıve Bayes classifier described above, what is the posterior probability that data object F in Figure 8 is Positive?

# %% [markdown]
# #### QUESTION 15: Using the Na¨ıve Bayes classifier described above, how will F, G, and H in Figure 8 be classified?

# %% [markdown]
# #### QUESTION 16: In a store five consumers denoted C1–C5 have purchased the items given in Figure 9, where 1 indicate that a given consumer purchased the item and 0 that the consumer did not purchase the item.

# %% [markdown]
# #### QUESTION 17: We note that association rules can be written interchangeably as {A,B}! {C} or {C} {A,B}. What is the confidence of the rule {Diaper} {Bread,Milk} and {Beer} {Jam}?

# %% [markdown]
# #### QUESTION 18: Consider a dataset where we have four different features: A, B, C and D that are used in a linear regression problem. Figure 10 shows the sum of square residual error, i.e.,  SSE = Pi(ytrue i −yest i )2 on the test sets averaged across 10 cross-validation folds when using different combinations of the features. We will apply a backward feature selection algorithm. Which feature set will the selection algorithm choose?

# %% [markdown]
# TIP: Remember that after removing a feature, you cannot use it again. When selecting A, B, D no two-feature options with C are available.

# %% [markdown]
# #### QUESTION 19: Which statement about the kmeans algorithm and the Gaussian Mixture Model (GMM) is wrong?

# %% [markdown]
# #### QUESTION 20: In a study of prostate cancer, a classification model was created with the confusion matrix illustrated in Figure 11. True indicates that the tumor is malignant and false that it is benign. Which statement is correct?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### QUESTION 21: Three different classification approaches have been used on a dataset. The training data as well as the decision boundaries obtained for each approach is given in figure 12A–12C. Which classification methods have been used to generate each of the decision boundaries A, B and C?

# %% [markdown]
# TIP: Decision trees have 90 degree turns on their decision boundries. Logistic regression has a linear decision boundry.

# %% [markdown]
# #### QUESTION 22: Which statement about crossvalidation is correct?

# %% [markdown]
# #### QUESTION 23: When training a decision tree we will use the classification error as impurity measure I(t) given by I(t) = 1 − maxi[p(i|t)] where p(i|t) denotes the fraction of data objects belonging to class i at a given node t. We will use Hunt’s algorithm to grow the tree and recall that the purity gain is given by  = I(Parent) −Pk j=1 N(vj ) N I(vj) where N is the total number of data objects at the parent node, k is the number of child nodes and N(vj) is the number of data objects associated with the child node, vj . We will consider classification of wine into Red and White wine. At a potential split we have

# %% [markdown]
# Challenge: Naive Bayes, GMM, purity gain.

# %% [markdown]
# #### QUESTION 24: In the analysis of car prices the following attributes were collected for each car: The number of kilometers the car had driven (denoted mileage), the make (brand) of the car (denoted make) and the year the car was produced (denoted year). Which statement about the three attributes is correct?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### QUESTION 25: We consider a data set with 10 data objects denoted A–J, that theoretically should lie in one cluster; however, we suspect there might be one or more outliers in the data set. To examine this, we plot the distance to the k’th nearest neighbor for k 2 {1, 2, 3, 4} (see Figure 13). Based on the plot, which statement is false?

# %% [markdown]
# # Fall 2011

# %% [markdown]
# Question 1. Consider the data set described in Table 1. Which statement about the attributes in the data set is correct?

# %% [markdown]
# Question 2. Consider the data set described in Table 1. Each attribute in the data set is standardized, and we carry out a principal component analysis (PCA) on the standardized input data, x1{x6. The singular values obtained are: 1 = 17:0, 2 = 15:2, 3 = 13:1, 4 = 13:0, 5 = 11:8, 6 = 11:3. The rst and second principal component directions are: Which one of the following statements is incorrect?

# %%
data = [17.0, 15.2, 13.1, 13.0, 11.8, 11.3]
var_exp = [float(n)/sum(data) for n in data]
var_exp
# Out:
# [0.20884520884520882,
#  0.18673218673218672,
#  0.1609336609336609,
#  0.1597051597051597,
#  0.14496314496314497,
#  0.13882063882063883]

# %% [markdown]
# Question 3. Consider the data set in Table 1. We would like to predict the birth weight y based on the six attributes x1{x6. In order to do so we t a linear regression model with Forward selection as well as a linear regression with Backward selection using ve-fold cross-validation. Which of the following statements is correct?

# %% [markdown]
# Question 4. A linear regression model has been tted to the data in Table 1 using ve-fold crossvalidated Forward and Backward selection. Figure 1 shows the results in terms of which attributes were selected in each cross-validation fold. Which of the following statements is correct?

# %% [markdown]
# Question 5. A linear regression model has been tted to the data set in Table 1 where the attributes Age and PV have been removed since they were neither selected by Forward nor Backward selection. Furthermore, they are correlated with the remaining attributes. The tted model, f(x), is given by

# %% [markdown]
# Question 6. Ten mothers, denoted m1;m2; : : : ;m10, have been randomly selected from the data set described in Table 1. We here consider only the attributes MW, HT, UI, BW, and the continuous attribute MW has been binarized in terms of the attribute's values being above or below the median value of all the 189 observations. BWL and BWH denotes a low birth weight baby and a high birth weight baby respectively. The binarized data is given in Table 2. What are all the frequent itemsets with support greater than 45%?

# %% [markdown]
# Question 7. Consider the data in Table 2. What is the condence of the association rule fBWLg   fMWL, HTNg?

# %% [markdown]
# Question 8. Consider the data set in Table 2. A mother who has a low weight, does not have a history of hypertension nor uterine irritability is just about to give birth to a baby. We would like to predict if the baby will have a low birth weight. For the mother we have MWL = 1, HTN = 1, UIN = 1. We will classify the mother considering only the attributes MWL; HTN; and UIN; based on the data in Table 2 only. We will use a Nave Bayes classier that assumes independence between these attributes. What is the probability that the weight of the baby will be low, i.e., BWL = 1?

# %% [markdown]
# Question 9. Table 3 shows the Euclidean distance between the ten selected mothers based on all the 6 attributes x1{x6 in Table 1. We recall that the KNN density and average relative density for the observation x is given by density(x;K) =  1 K X y2N(x;K) distance(x; y) 􀀀1 a.r.d.(x;K) = density(x;K) 1 K X y2N(x;K) density(y;K) ; where N(x;K) is the set of K nearest neighbors of observation x and a.r.d(x;K) is the average relative density of x using K nearest neighbors. Based on the the data in Table 3, what is the average relative density for observation m2 for K = 2 nearest neighbors?

# %% [markdown]
# Question 10. Out of the ten mothers in the data in Table 2, m3, m4, m6, m7, m8, and m9 gave birth to a baby with low birth weight, i.e., BWL = 1. Based on the distances in Table 3, we will use K-nearest neighbor classication with K = 1 to classify each observation. The performance of the classier is estimated using leave-one-out cross-validation. Which of the following statements about the leaveone- out crossvalidation error is incorrect?

# %% [markdown]
# Question 11. In a very large unpublished study the following ndings were made: • 60% of mothers that have a history of hypertension give birth to a baby with low birth weight. • 8% of mothers that do not have a history of hypertension give birth to a baby with low birth weight. • 10% of all mothers have a history of hypertension. A mother gives birth to a baby with low birth weight. What is the probability the mother has a history of hypertension according to the unpublished study?

# %% [markdown]
# Question 12. We will consider a two-class classication problem. A classier has been trained that gives a score t to each observation. Figure 2 shows the value of the score for each observation, as well as the density of the two classes as a function of the score t estimated using a kernel density estimator. Figure 3 shows the ROC curves for three dierent classiers. Which of the three ROC curves corresponds to the classier that scores the observations according to Figure 2?

# %% [markdown]
# Question 13. A dataset with two attributes x1 and x2 contains the four classes illustrated in Figure 4. Which of the following statements is correct?

# %% [markdown]
# Question 14. Three dierent classiers are trained on all the available data in Figure 4 using only x1 and x2 as attributes. The data as well as the decision boundaries of each of the three classiers are given in Figure 5. Which of the following statements is correct?

# %% [markdown]
# Question 15. We would like to combine classiers in order to improve the classication performance. Which one of the following statements is correct?

# %% [markdown]
# Question 16. Out of the three classiers in Figure 5, it turns out that classier B is the worst performing classier. In Figure 6 we inspect the confusion matrix of this classier. Which of the following statements is incorrect?

# %% [markdown]
# Question 17. Which of the following statements about decision trees is incorrect?

# %% [markdown]
# Question 18. The data in Table 4 shows whether or not eight keywords occur in ve news articles (i.e., the data has eight attributes and ve observations). Which statement about the data is incorrect?

# %% [markdown]
# Question 19. What is the empirical covariance between the two attributes \Opera" and \Orchestra" in the data in Table 4?

# %% [markdown]
# Question 20. The following proposed clustering procedure (step 1 to 3 below) for the ve articles in Table 4 contains an error: 1) The articles are clustered using k-means with k = 2. 2) The simple matching coecient (SMC) is used as similarity measure. 3) The centroids are computed as the component-wise mean. Which statement about the erroneous clustering procedure is correct?

# %% [markdown]
# Question 21. Use agglomerative hierarchical clustering with complete linkage to cluster the ve articles in Table 4. As a distance measure use d(x; y) = 1􀀀J(x; y) where J is the Jaccard coecient. Which of the four clusterings in Figure 7 is the resulting hierarchical clustering?

# %% [markdown]
# Question 22. You are told that the news articles in Table 4 belong to two groups (indicated in red and black respectively in the table):

# %% [markdown]
# Question 23. Consider a decision tree optimized to classify the news articles in Table 4 into the two groups described in Question 22. The decision tree is optimized with Hunt's algorithm using the Gini index as impurity measure, and no pruning is performed. Which of the following statements is correct?

# %% [markdown]
# Question 24. Which statement about linear regression is incorrect?

# %% [markdown]
# Question 25. Consider the following data x -1 0 1 2 y 2 2 4 8 A linear regression model, f(x) = w0 + w1x; is t to the data using the least square method. What are the optimal parameters?

# %% [markdown]
# Question 26. Consider the data in Table 5 illustrated by the boxplot in Figure 8. Which statement is incorrect?

# %% [markdown]
# # Fall2014

# %% [markdown]
# Question 1.
# Consider the six attributes with their description in
# table 1. Which of the following statements about the
# type of the attributes is true?

# %% [markdown]
# Question 2. A 1-dimensional dataset is composed of
# N = 60 observations; exactly 40 of these observations
# take the value 1, 10 take the value 2 and the remaining
# 10 observations take the value 3. Which of the four
# boxplots in g. 1 is a boxplot of the dataset?

# %% [markdown]
# Question 3. A principal component analysis is
# applied to a dataset composed of 1000 data points.
# After applying the principal component analysis, the
# datapoints (gray points) along with the right singular
# vectors (i.e. the principal directions) (black arrows)
# are plotted. Which of the subplots A;B;C;D of gure
# g. 2 corresponds to this description?

# %% [markdown]
# Question 4. A principal component analysis is
# carried out on a dataset comprised of three data points
# x1; x2 and x3 collected in a NM matrix X such that
# each row of the matrix is a data point. Suppose the
# matrix ~X corresponds to X with the mean of each
# columns substracted i.e.

# %% [markdown]
# Question 5. Consider a feedforward neural network
# shown in g. 3. The network has no bias weights.
# Suppose the weights of the neural network are
# trained to be w31 = 0:5, w41 = 0:4, w32 = 􀀀0:4,
# w42 = 0, w53 = 􀀀0:4, w54 = 0:1 and the activation
# function of all ve n1; : : : ; n5 nodes is the thresholded
# linear function

# %% [markdown]
# Question 6. Suppose a neural network is trained
# on input/output pairs (xi; yi) on a dataset of N = 5
# observations. The response of the neural network for
# input xi is denoted as ^yi and the values can be seen
# in table 2. We convert the continuous output ^yi to a

# %% [markdown]
# Question 7. Suppose the points in the scatter plot
# g. 4 was generated from a Gaussian mixture-model
# (GMM) of the form

# %% [markdown]
# Question 8. A factory produces cars. We consider
# three properties of the cars produced by the factory
# and each property can only take two values:
# • The color which can be either red or blue.
# • The weight which can be either heavy or light.
# • The model which can be either 2-doors or 4-doors.
# There are thus 23 = 8 possible car types such as (red,
# heavy,2-doors) or (blue,light,4-doors).
# Suppose you are given the following information
# about cars produced from the factory:
# • The probability a car has four doors is 0.5
# • The probability a car is heavy given it has four
# doors is 0.8
# • The probability a car is heavy given it has two
# doors is 0.2
# • The probability a car is heavy and red is 0.1
# Given the above information, what is the probability a
# car is blue given it is heavy?

# %% [markdown]
# Question 9. Consider a one-dimensional data set of
# features X and 3-class responses y shown in table 3;
# there are thus N = 7 observations. Suppose a decision
# X 1 3 1 2 1 4 2
# y 2 2 2 0 0 1 0
# Table 3: Table of data and responses.
# tree is used to classify y on X. Consider an attempted
# split at X = x1 > 2:5. What is the impurity gain  of
# this split for the data set if the classication error is
# used as impurity measure?

# %% [markdown]
# Question 10.
# In table 4 is given the pairwise cityblock distances
# between 8 observations along with a description of the
# dataset. What can be concluded about the similarity
# of observation o1 and o3?

# %% [markdown]
# Question 11. In table 4 is given the pairwise cityblock
# distances between 8 observations. A hierarchical
# clustering is used to cluster these nine observations using
# group average linkage. Which of the dendrograms
# shown in g. 5 corresponds to the clustering?

# %% [markdown]
# Question 12. Consider again the distances in table 4.
# We will predict the label indicated by the blue color,
# i.e. observations o1; : : : ; o4 belong to class C1 and
# observations o5; : : : ; o8 to class C2. This will be done
# using a k-nearest neighbor (KNN) classier based on
# the cityblock distance measure indicated in table 4.
# We will use leave-one-out cross validation (i.e. the
# observation that is being predicted is left out) using
# one-nearest classier, i.e. k = 1. What is the accuracy
# if all N = 8 observations are classied?

# %% [markdown]
# Question 13. Consider again the distances in table 4.
# We wish to compute the average relative KNN density
# (a.r.d) of the observations in table 4 using the cityblock
# distance indicated by the table. Letting d(x; y) denote
# the cityblock distance metric this is dened as

# %% [markdown]
# Question 14. Consider again the distances in table 4.
# Suppose we wish to perform mixture modelling (see
# chapter 9.2 of "Introduction to data mining") and we
# consider mixture distributions of the form ( > 0):
# p(xj) =
# 1
# 2
# exp(􀀀d(x; )=)
# Suppose we consider K = 8 mixture components, the
# parameter 1; : : : ; 8 of each mixture component is
# taken to be the position of the observations o1; : : : ; o8
# and each mixture component is weighted equally in the
# full mixture distribution. Suppose we set  = 4 and
# let d denote the cityblock distance metric. What is the
# probability density at observation o1?

# %% [markdown]
# Question 15. Consider the observations in table 5.
# Suppose we only consider the rst two features f1; f2
# and train a Naive-Bayes classier to classify between
# class C1 (black) and C2 (blue) based on these two features
# alone. Suppose an observation has f1 = 0; f2 = 1,
# what is the probability this observation belongs to class
# C1 according to the Naive-Bayes classier?

# %% [markdown]
# Question 16. Consider table 5. Suppose we
# consider the binary matrix as a market-basket problem
# consisting of N = 10 "transactions" and M = 6
# "items" f1; : : : ; f6. Which of the following options
# represents all itemsets with a support (i.e. support
# count divided by number of transactions) greater than
# 0.41?

# %% [markdown]
# Question 17. Consider again table 5. Suppose we
# consider the binary matrix as a market-basket problem
# consisting of N = 10 "transactions" and M = 6
# "items" f1; : : : ; f6. What is the condence of the rule
# ff1; f6g ! ff4; f5g

# %% [markdown]
# Question 18. Consider a system which attempts
# to classify observations based on the value of four observed
# features x1; x2; x3; x4. Suppose we wish to examine
# which subset of features gives the least misclassi-
# ed observations on test data. In table 6 is shown how
# dierent combinations of features give rise to dierent
# number of misclassied observations on a training and
# test set. Which of the following statements is true?

# %% [markdown]
# Question 19. Consider the classication problem
# given in g. 7. Suppose the problem is solved using
# the following four classiers
# (1NN) A 1-nearest neighbour classier
# (TREE) A decision tree
# (LREG) Logistic regression
# (NNET) An articial neural network with four hidden
# units
# All classiers are using only the two attributes x1; x2,
# corresponding to the position of each observation, as
# well as the class label. Which of the descriptions
# (1NN),(TREE),(LREG),(NNET) matches the boundariers
# of the four plots (P1; P2; P3; P4) indicated in
# g. 6?

# %% [markdown]
# Question 20. Consider the simple 1-dimensional
# data set comprised of N = 7 observations as shown in
# table 7. Suppose we wish to apply K-means clustering
# to the dataset and the K = 3 one-dimensional cluster
# centers are initialized in 1 = 4, 2 = 7 and 3 = 14.
# After terminating of the K-means clustering algorithm,
# what are the nal (rounded) cluster centers 1; 2; 3?

# %% [markdown]
# Question 21. Suppose we wish to solve the two-class classication
# problem in g. 7 using a classication tree of the
# form g. 8. What rules, acting on the coordinates
# x = (x1; x2), should be assigned to the three internal
# nodes A;B and C for the tree to give rise to the
# indicated decision boundary?

# %% [markdown]
# Question 22.
# Suppose logistic regression classier is trained on observations
# from two classes as shown in the top pane of
# g. 9 and the trained classier produces an estimate of
# the probability of belonging to class 1 as shown in the
# bottom pane. If the classier takes the following form
# f(x1; x2) = logistic(w0 + w1x1 + w2x2 + w3x1x2)
# what are the values

# %% [markdown]
# Question 23. Consider a two-dimensional data set
# consisting of N = 7 observations as shown in g. 10.
# The dataset consist of two classes indicated by the
# black crosses (class 1) and red circles (class 2). In
# the gure, the decision boundary for four K-nearest
# neighbor classier (KNN) is shown such that the lighter
# brown color indicates Class 2 (red circles) and the
# darker brown color indicates Class 1 (black crosses).
# Suppose K is restricted to the values 1; 3; 5; 7, which
# of the following statements are true about values of
# k1; k2; k3 and k4?

# %% [markdown]
# Question 24. Suppose a small network is trained
# on a binary classication dataset containing N = 1000
# points. The output of the neural network is continuous
# and restricted to ^y 2 [0; 1]. To evaluate the performance
# on the network, the network makes predictions
# on a test set of Ntest = 1000 points. By thresholding
# the output of the neural network at dierent levels, i.e.
# for each level  assign an output ^yi to class 0 if ^y
# and otherwise to class 1, one obtains dierent values of
# the TP, TN, FP and FN. This allows us to draw the
# ROC curve shown in g. 11. Which of the true positive
# rate (TPR), and false positive rate (FPR) curves
# A,B,C or D shown in g. 12 corresponds to the ROC
# curve in g. 11?

# %% [markdown]
# Question 25. Consider the true positive rate (TPR),
# and false positive rate (FPR) as a function of the
# threshold  for the problem of N = 1000 observations
# shown in g. 12(A). Suppose we consider predictions
# made at a threshold of  = 0:3, and suppose we are
# told that the number of true negatives at  = 0:3 is
# TN = 489, the TPR at this threshold is TPR = 0:412
# and the FPR at this threshold is FPR = 0:164. What
# is the (approximate) number of true positives (TP) of
# the model at this threshold?

# %% [markdown]
# Question 26. Suppose Jane wishes to apply a decision
# tree classier to a binary classication problem of
# only N = 4 observations. Training and applying the
# decicion tree to the full dataset X and y1; : : : ; y4 gives
# predictions ^y1; : : : ; ^y4 shown in table 8. To improve
# performance Jane decides to apply AdaBoost (the version
# in the lecture notes, chapter 15), however Jane
# implements AdaBoost such that instead of sam-pling
# the N elements of the training sets Di with replacement,
# Jane samples the training sets without replacement,
# i.e. the training set Di is simply the full
# dataset. Suppose Jane applies AdaBoost for k = 1
# round of boosting, what is the resulting (approximate)
# value for the weights w?

# %% [markdown]
# Question 27. Alice is considering a linear regression
# model for a dataset comprised of N = 1000 observations.
# She wishes to both select the optimal regularization
# strength as well as estimate the generalization error
# of the model at the optimal regularization strength.
# To simplify the problem, she only considers the following
# 6 possible values of the regularization strength :
#  = 10􀀀2; 10􀀀1; 100; 101; 102; 103:
# Alice opts for a two-level strategy in which she uses
# the hold-out method to estimate the generalization error
# and cross-validation is used to select the optimal
# regularization strength, i.e. the dataset is rst divided
# into a validation set Dvalidation, comprised of 20% of the
# full dataset, and the remainder DCV is used for crossvalidation.
# Alice uses standard K = 10 fold crossvalidation
# to select the optimal regularization strength
# on DCV and, having estimated the optimal regularization
# strength, uses the hold-out method on DCV and
# Dvalidation to estimate the generalization error.
# Suppose for any xed value of the regularization
# strength, the time taken to train the weights of the
# linear regression model on a dataset of size Ntrain is
# N2
# train units of time and the time taken to test a trained
# model on a dataset of size Ntest is 1
# 2N2
# test units of time.
# Suppose the duration of all other tasks is neglible, what
# is the total time taken for the entire procedure?

# %% [markdown]
# # Spring2014

# %% [markdown]
# Question 1. We will consider a dataset on wholesale
# taken from http://archive.ics.uci.edu/ml/
# datasets/Wholesale+customers. The data set includes
# 440 customers. The customers are from Lisbon
# and Oporto in Portugal as well as one additional region
# here denoted Other. The data provides the costumers'
# annual expenditures in monetary units of fresh products
# (FRESH), milk products (MILK), grocery products
# (GROCERY), frozen products (FROZEN), detergents
# and paper products (PAPER), and delicatessen
# products (DELI). The attributes of the data and their
# abbreviations are also given in Table 1.
# In Figure 1 is given a boxplot of the six input
# attributes of the data. Which one of the following
# statements is correct?

# %% [markdown]
# Question 2. Which one of the following statements
# regarding the wholesale data is correct?

# %% [markdown]
# Question 3. A principal component analysis is
# carried out on the wholesale data based on x1{x6.
# The mean is subtracted from each attribute and the
# singular value decomposition (SVD) is applied to the
# data matrix of size 440  6. From the SVD we obtain
# for the matrices S and V :

# %%
S = [2.69, 2.35, 1.05, 0.83, 0.49, 0.31]
S2 = [n**2 for n in S]
var_exp = [float(i**2)/sum(S2) for i in S]
var_exp
# Out:
# [0.4860945036342384,
#  0.37098117719767304,
#  0.07406188281764318,
#  0.04627776061049831,
#  0.016129032258064516,
#  0.006455643481882549]

# %%
sum(var_exp[0:4])
# Out:
# 0.9774153242600528

# %% [markdown]
# Question 4. Which one of the following statements
# pertaining to the principal component analysis is cor-
# rect?

# %% [markdown]
# Question 5. We will predict whether a consumer is
# from Lisbon (y=0) or Oporto (y=1) by discarding observations
# from the Other region included in the wholesale
# data. After discarding the observations pertaining
# to the Other region we standardize the attributes x1{x6
# (i.e., for each attribute subtract the mean and divide
# by the standard deviation) and t a logistic regression
# model. We obtain the following model for the prediction
# of the origin of the consumer:
# f(x1; x2; x3; x4; x5; x6) = logit(􀀀0:51 􀀀 0:11x1 􀀀 0:36x2
# +0:44x3 + 0:39x4 + 0:09x5 􀀀 0:28x6);
# where logit(w) = 1
# 1+exp(􀀀w) is the logit function.
# Which one of the following statements about the model
# is correct?

# %% [markdown]
# Question 6. In Table 2 is given the pairwise
# distances between the rst three costumers from each
# of the three regions, i.e. Lisbon, Oporto, and the
# Other region. A hierarchical clustering is used to
# cluster these nine observations using complete (i.e.,
# maximum) linkage. Which one of the dendrograms
# given in Figure 2 corresponds to the clustering?

# %% [markdown]
# Question 7. In order to predict REGION we will
# use a k-nearest neighbor (KNN) classier based on
# the Euclidean distance between the nine observations
# given in Table 2. We will use leave-one-out crossvalidation
# for the KNN in order to classify whether the
# nine considered observations constitute costumers from
# Lisbon (given in black, i.e. observations O1, O2, O3),
# Oporto (given in red, i.e. observations O4, O5, O6) or
# the Other region (given in blue, i.e. observations O7,
# O8, O9). We will use a one-nearest neighbor classier,
# i.e. K = 1. The analysis will be based only on the data
# given in Table 2. Which one of the following statements
# is correct?

# %% [markdown]
# Question 8. We suspect that observation O1 may
# be an outlier. In order to assess if this is the case
# we would like to calculate the average relative KNN
# density based on the observations given in Table 2
# only. We recall that the KNN density and average
# relative density for the observation x are given by:
#
# where N(x;K) is the set of K nearest neighbors of
# observation x and a.r.d(x;K) is the average relative
# density of x using K nearest neighbors. Based on the
# data in Table 2, what is the average relative density
# for observation O1 for K = 1 nearest neighbors?

# %% [markdown]
# Question 9. Using the Euclidean distances given
# in Table 2 and reproduced in terms of observation
# O1 in Table 3 we would like to quantify if O1 is
# an outlier using a Gaussian kernel density estimator
# where we use the eight observations O2, O3, : : :, O9 to
# estimate the density at observation O1. We note that
# d(Oa;Ob)2 = jjxa 􀀀 xbjj22
# = (xa 􀀀 xb)>(xa 􀀀 xb). The
# Gaussian kernel density estimator is given by
# Thus, N = 8 and since we consider 6 features x1{x6,
# M = 6. In our analysis we will use  = 1. What is
# the density at observation O1 using only observations
# O2{O9 in the above Gaussian kernel density estimator?

# %% [markdown]
# Question 10. By thresholding all the dendrograms
# in Figure 2 at the level of three clusters we obtain the
# following clusters:
# Cluster 1: O2, O3, O4, O5, O6, O7, O8
# Cluster 2: O9
# Cluster 3: O1
# Let mij denote the number of observations of class
# Let the class an observation
# belongs to be dened in terms of the region
# the customer is from where O1, O2, O3 correspond to
# Lisbon, O4, O5, O6 correspond to Oporto, and O7,
# O8, O9 to the Other region. What is the purity of the
# above clustering?

# %% [markdown]
# Question 11. We consider the twelve costumers
# given in Table 4. We will consider this data set a
# market basket problem in which the twelve customers
# have various combinations of the six items denoted
# MH, ML, PH, PL, DH, DL. Which one of the proposed
# solutions below includes all the frequent itemsets with
# support of more than 40 %?

# %% [markdown]
# Question 12. What is the condence of the association
# rule fML;DLg ! fPLg?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 13. Six of the twelve considered costumers
# in Table 4 are from Lisbon (i.e., LIS1{LIS6 given in
# black) whereas six of the costumers are from Oporto
# (i.e., OPO1{OPO6 given in red). We would like to
# predict whether a costumer is from Lisbon or Oporto
# using the data in Table 4 and the attributes MH, PH,
# and DH. We will apply a Nave Bayes classier that
# assumes independence between the three attributes.
# Given that a costumer had these three attributes (i.e.,
# MH = 1, PH = 1, DH = 1) what is the probability that
# the costumer is from Lisbon according to the Nave
# Bayes classier. I.e., what is
# P(LisbonjMH = 1; PH = 1;DH = 1) according to the
# Nave Bayes classier?

# %% [markdown]
# # Fall 2015

# %% [markdown]
# Question 1. Consider the Chronic Kidney Disease
# dataset with attributes given in Table 11. Notice, the
# dataset has been pre-processed for this exam and only
# some of the attributes in the original data are presently
# considered whereas persons with missing data have
# been removed. A boxplot of the attributes are given in
# Figure 1. Which of the following statements is true?

# %% [markdown]
# Question 2. A principal component analysis is
# carried out on the Chronic Kidney Disease dataset
# based on the attributes x1; : : : ; x6 found in Table 1.
# We standardize the data, i.e. by subtracting the mean
# from each attribute and dividing each attribute by
# its standard deviation to form the standardized data
# matrix ~X of size 294 subjects6 attributes and apply
# a singular value decomposition USV > = ~X where
#
# We note that the entries of the matrices above have
# been rounded. Which one of the following statements
# is true?

# %%
import numpy as np

def var_exp(sigma):
    '''Prints variance explained as well as cumsum'''
    S2 =[n**2 for n in sigma]
    variance_explained = [float(i**2)/sum(S2) for i in sigma]
    print('Values: {}'.format(variance_explained))
    print('CumSum: {}'.format(np.cumsum(variance_explained)))
    
var_exp([27.9, 18.0, 15.8, 14.5, 11.1, 8.4])
# Out:
# Values: [0.44326820684824636, 0.18450289567044595, 0.1421583422073152, 0.11972757350219525, 0.07016235115912235, 0.0401806306126749]
# CumSum: [ 0.44326821  0.6277711   0.76992944  0.88965702  0.95981937  1.        ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 3. In Figure 2 is given the data projected
# onto the rst two principal components where
# observations corresponding to CKD = 1 is marked by
# red crosses (x) whereas observations corrresponding to
# CKD = 0 are makred by black circles (). Which
# statement is correct?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 4. A Gaussian Mixture model is tted to
# the data projected onto the rst two principal components
# using K=3 mixture components. The estimated
# density is shown in Figure 3. Which of the following
# expressions corresponds to the estimated density?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 5. Using the data projected onto the rst
# two principal components four dierent classiers are
# trained on half of the data and their decision boundaries
# given in Figure 4. Which one of the following
# statements is true?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 6. A logistic regression classier is trained
# using only combinations of x1, x2, x3 and x4 and the
# error rate on the training and test data where half the
# data again is used for training and the other half for
# testing is given in Table 2. Which one of the following
# statements is correct?

# %% [markdown]
# Question 7. The confusion matrix of a logistic
# regression classier evaluated on the test data is given
# in Figure 5. To generate the confusion matrix data has
# been split in two, half of the data is used for training
# the classier and the other half for testing. We will
# presently consider CKD=1 as the positive class and
# CKD=0 as the negative class of the classier. Which
# one of the following statements is true?

# %% [markdown]
# Question 8. The performance of four dierent
# classiers are given in terms of their Receiver Operator
# Characteristic (ROC) curve in Figure 6. One of the
# classiers correspond to the classier with confusion
# matrix given in Figure 5, which one?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 9. In Table 3 is given the pairwise distances
# between the rst four subjects with and the rst three
# subjects without chronic kidney disease. A hierarchical
# clustering is used to cluster these seven observations
# using complete (i.e., maximum) linkage. Which one of
# the dendrograms given in Figure 7 corresponds to the
# clustering?
